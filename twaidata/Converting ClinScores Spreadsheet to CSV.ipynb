# %%
import pandas as pd
import numpy as np

# %%
input_file = "/home/s2208943/ipdis/data/core_data/updated_spreadsheet/CVDclinScores.xlsx"
output_file = "/home/s2208943/ipdis/data/preprocessed_data/Ed_CVD_tabledata/CVD_clinScores_dataset_updated.csv"

# %%
df = pd.read_excel(input_file, engine='openpyxl')

# %%
df.to_csv(output_file)

# %%
df
# Out:
#          ID  sbjGroup        age  sex  diabetes  hypertension  \
# 0    CVD001         0  76.004929    2         0             0
# 1    CVD002         0  77.144031    1         1             1
# 2    CVD003         0  92.571194    1         0             1
# 3    CVD011         0  72.571194    2         0             1
# 4    CVD013         0  77.239869    2         0             0
# ..      ...       ...        ...  ...       ...           ...
# 245  CVD172         2  66.000000    1         0             1
# 246  CVD188         2  78.000000    1         0             1
# 247  CVD191         2  71.000000    2         0             1
# 248  CVD216         2  71.000000    1         0             1
# 249  CVD238         2  58.000000    1         0             0
#
#      hyperlipidaemia  smoking         SBP        DBP  ...        WMH  PVWMH  \
# 0                1.0      0.0  128.666667  76.000000  ...  32.848000    2.0
# ...
